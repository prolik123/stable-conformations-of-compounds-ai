# %%
from utils.QM9DataLoader import load_qm9

# %%
dataset = load_qm9()
limit = 100

# %%
import atoms_distribution

atoms_distribution.analise_and_plot(dataset, limit)

# %%
import centroid_distance

centroid_distance.analise_and_plot(dataset, limit)

# %%
import elements_type_projection

elements_type_projection.analise_and_plot(dataset, limit)

# %%
import atoms_position_to_energy_distribution

atoms_position_to_energy_distribution.analise_and_plot(dataset, limit)

# %%
import stability

stability.analyse_and_plot(dataset, limit)

# %%
import geom_sample_analyse
geom_sample_analyse.analyse_and_polt()
# Out:
# The file qm9_crude.msgpack.tar.gz is already downloaded at ../Datasets/GEOM\qm9_crude.msgpack.tar.gz.
# File already extracted to ../Datasets/GEOM\qm9_crude.msgpack
# The file qm9_featurized.msgpack.tar.gz is already downloaded at ../Datasets/GEOM\qm9_featurized.msgpack.tar.gz.
# File already extracted to ../Datasets/GEOM\qm9_featurized.msgpack
# Result for: O=C1CC(=O)[C@@H](O)CO1
